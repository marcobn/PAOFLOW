# %%
from PAOFLOW import PAOFLOW
import numpy as np
from PAOFLOW import GPAO

pplt = GPAO.GPAO()

# %%
paoflow = PAOFLOW.PAOFLOW(savedir='./Bi.save')

paoflow.read_atomic_proj_QE()
paoflow.projectability()
paoflow.pao_hamiltonian()

paoflow.adhoc_spin_orbit(phi=0.0,theta=0.0,soc_strengh={ 'Bi': [1.5,0.0] })


path = 'xX-G-X'
special_points = {'G':[0.0, 0.0, 0.0],'X':[0.5,0.0,0.0],'xX':[-0.5,0.0,0.0]}
paoflow.bands(ibrav=0, nk=100, band_path=path, high_sym_points=special_points)

paoflow.site_projected_bands(site_proj=np.array([0,1,2,3,4,5,18,19,20,21,22,23]))
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# Serial execution
# Estimated maximum array size: 0.06 GBytes
#
# Initialization in:                          0.004 sec
# Projectability in:                         41.108 sec
# Building Hks in:                            0.101 sec
# k -> R in:                                  0.016 sec
# adhoc_spin_orbit in:                        0.044 sec
# Bands in:                                   7.852 sec
# site_projeted_bands in:                    11.888 sec

# %%
  # Ploting Site Projection

outputdir='./output/' 
f_band = outputdir + 'site-projected-bands_0.dat'
f_symp = outputdir + 'kpath_points.txt'

label       = '$\epsilon-\epsilon_{F}$ (eV)'
cbar_label  = 'Edge Sites Projection'
filename    = 'edge_states_projection.png'

pplt.plot_weighted_bands( outputdir, f_band, f_symp, None, cbar_label, label, filename, y_lim = (-1,1))
