# %% [markdown]
# # Important Notes
# (1) When using VASP, PAOFLOW requires spglib. All examples show below are run with ISYM = 2 in VASP. ISYM = -1 and 0 also work (For LSORBIT=T and Magnetic system, ISYM = -1 and 0 are equivalent, i.e. full grid).  Make sure the PAOFLOW printed space group is correct.
# (2) Either run VASP SCF with LWAVE=T and a fine K-mesh, or run VASP SCF (LCHARG=T) first with a coarse K-mesh, then non-SCF (ICHARG=11 and LWAVE=T) with finer K-mesh. The later one may save some computation. Gamma-centered K-mesh is strongly recommended.
# (3) If magnetic, MAGMOM in INCAR is necessary. This is because PAOFLOW reads the MAGMOM tag in vasprun.xml to determine the symmetry, which comes from INCAR.
# (4) PAOFLOW reads "vasprun.xml" and "WAVECAR", make sure they are in the directory.
# (5) If using VASP, when calling pao_hamiltonian(), DO NOT set "open_wedge=False" even if symmetry is turned off (ISYM = -1). This is because VASP might use a different set of k-mesh from PAOFLOW and a mapping between the k-points is required.

# %%
# Change PAOFLOW export directory if necessary
import sys
sys.path.append('../../')
from src.PAOFLOW import PAOFLOW
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Example01: Si

# %%
paoflow = PAOFLOW(savedir='./example01/nscf_nspin1/',  
                  outputdir='./example01/output_nspin1/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Fd-3m (227)
# Insulator: True
# Magnetic: False
# Number of kpoints: 72
# Number of electrons: 8.000000
# Number of bands: 18
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.11 GBytes
#
# Initialization in:                          0.034 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Si':['3S','3P','3D','4S','4P','4D']}
paoflow.projections(basispath=basis_path, configuration=basis_config)  # "internal=True" is optional, always use internal basis when dft == 'VASP'
# Out:
# atom: Si  AEWFC: ../../BASIS/Si\3S.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\3P.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\3D.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4S.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4P.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4D.dat           tau: [0. 0. 0.]
#       atwfc:   1  3S  l=0, m=1
#       atwfc:   2  3P  l=1, m=1
#       atwfc:   3  3P  l=1, m=2
#       atwfc:   4  3P  l=1, m=3
#       atwfc:   5  3D  l=2, m=1
#       atwfc:   6  3D  l=2, m=2
#       atwfc:   7  3D  l=2, m=3
#       atwfc:   8  3D  l=2, m=4
#       atwfc:   9  3D  l=2, m=5
#       atwfc:  10  4S  l=0, m=1
#       atwfc:  11  4P  l=1, m=1
#       atwfc:  12  4P  l=1, m=2
#       atwfc:  13  4P  l=1, m=3
#       atwfc:  14  4D  l=2, m=1
#       atwfc:  15  4D  l=2, m=2
#       atwfc:  16  4D  l=2, m=3
#       atwfc:  17  4D  l=2, m=4
#       atwfc:  18  4D  l=2, m=5
# atom: Si  AEWFC: ../../BASIS/Si\3S.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\3P.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\3D.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4S.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4P.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4D.dat           tau: [-2.58797155  2.58797155  2.58797155]
#       atwfc:  19  3S  l=0, m=1
#       atwfc:  20  3P  l=1, m=1
#       atwfc:  21  3P  l=1, m=2
#       atwfc:  22  3P  l=1, m=3
#       atwfc:  23  3D  l=2, m=1
#       atwfc:  24  3D  l=2, m=2
#       atwfc:  25  3D  l=2, m=3
#       atwfc:  26  3D  l=2, m=4
#       atwfc:  27  3D  l=2, m=5
#       atwfc:  28  4S  l=0, m=1
#       atwfc:  29  4P  l=1, m=1
#       atwfc:  30  4P  l=1, m=2
#       atwfc:  31  4P  l=1, m=3
#       atwfc:  32  4D  l=2, m=1
#       atwfc:  33  4D  l=2, m=2
#       atwfc:  34  4D  l=2, m=3
#       atwfc:  35  4D  l=2, m=4
#       atwfc:  36  4D  l=2, m=5
# Projections in:                            13.491 sec

# %%
paoflow.projectability()
# Out:
# Projectability vector  [0.99310907 0.99065816 0.98813499 0.985395   0.98769841 0.98595731
#  0.98250478 0.98179844 0.98463947 0.98420823 0.96864238 0.97012678
#  0.9667213  0.96248319 0.91663707 0.9402235  0.92657198 0.84888903]
# # of bands with good projectability > 0.95 = 14
# Range of suggested shift  14.93793178  ,  18.82883178
# Projectability in:                          0.028 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            1.983 sec
# k -> R in:                                  0.186 sec

# %%
paoflow.bands(ibrav=2,nk=500)
# Out:
# Bands in:                                   0.757 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
plt.plot(eband[:,0],color='black')
for ib in range(1,eband.shape[1]):
    plt.plot(eband[:,ib],color='black')
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('Si_VASP.png',bbox_inches='tight')

# %% [markdown]
# # Example 01: Si (nspin = 2)

# %%
paoflow = PAOFLOW(savedir='./example01/nscf_nspin2/',  
                  outputdir='./example01/output_nspin2/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Fd-3m (227)
# Insulator: True
# Magnetic: False
# Number of kpoints: 72
# Number of electrons: 8.000000
# Number of bands: 18
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.21 GBytes
#
# Initialization in:                          0.074 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Si':['3S','3P','3D','4S','4P','4D']}
paoflow.projections(basispath=basis_path, configuration=basis_config)  # "internal=True" is optional, always use internal basis when dft == 'VASP'
# Out:
# atom: Si  AEWFC: ../../BASIS/Si\3S.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\3P.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\3D.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4S.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4P.dat           tau: [0. 0. 0.]
# atom: Si  AEWFC: ../../BASIS/Si\4D.dat           tau: [0. 0. 0.]
#       atwfc:   1  3S  l=0, m=1
#       atwfc:   2  3P  l=1, m=1
#       atwfc:   3  3P  l=1, m=2
#       atwfc:   4  3P  l=1, m=3
#       atwfc:   5  3D  l=2, m=1
#       atwfc:   6  3D  l=2, m=2
#       atwfc:   7  3D  l=2, m=3
#       atwfc:   8  3D  l=2, m=4
#       atwfc:   9  3D  l=2, m=5
#       atwfc:  10  4S  l=0, m=1
#       atwfc:  11  4P  l=1, m=1
#       atwfc:  12  4P  l=1, m=2
#       atwfc:  13  4P  l=1, m=3
#       atwfc:  14  4D  l=2, m=1
#       atwfc:  15  4D  l=2, m=2
#       atwfc:  16  4D  l=2, m=3
#       atwfc:  17  4D  l=2, m=4
#       atwfc:  18  4D  l=2, m=5
# atom: Si  AEWFC: ../../BASIS/Si\3S.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\3P.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\3D.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4S.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4P.dat           tau: [-2.58797155  2.58797155  2.58797155]
# atom: Si  AEWFC: ../../BASIS/Si\4D.dat           tau: [-2.58797155  2.58797155  2.58797155]
#       atwfc:  19  3S  l=0, m=1
#       atwfc:  20  3P  l=1, m=1
#       atwfc:  21  3P  l=1, m=2
#       atwfc:  22  3P  l=1, m=3
#       atwfc:  23  3D  l=2, m=1
#       atwfc:  24  3D  l=2, m=2
#       atwfc:  25  3D  l=2, m=3
#       atwfc:  26  3D  l=2, m=4
#       atwfc:  27  3D  l=2, m=5
#       atwfc:  28  4S  l=0, m=1
#       atwfc:  29  4P  l=1, m=1
#       atwfc:  30  4P  l=1, m=2
#       atwfc:  31  4P  l=1, m=3
#       atwfc:  32  4D  l=2, m=1
#       atwfc:  33  4D  l=2, m=2
#       atwfc:  34  4D  l=2, m=3
#       atwfc:  35  4D  l=2, m=4
#       atwfc:  36  4D  l=2, m=5
# Projections in:                            22.937 sec

# %%
paoflow.projectability()
# Out:
# Projectability vector  [0.99310902 0.99065834 0.98813563 0.98539483 0.98769811 0.98595877
#  0.9825043  0.98180015 0.98463903 0.98420944 0.96864314 0.970127
#  0.96672217 0.96248311 0.91663678 0.94022273 0.92655815 0.84904813]
# # of bands with good projectability > 0.95 = 14
# Range of suggested shift  14.937893840000001  ,  18.828793840000003
# Projectability in:                          0.027 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            2.151 sec
# k -> R in:                                  0.240 sec

# %%
paoflow.bands(ibrav=2,nk=500)
# Out:
# Bands in:                                   1.116 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
plt.plot(eband[:,0,0],color='blue',alpha=0.6,label="up")
plt.plot(eband[:,0,1],color='red',alpha=0.6,label="down")
for ib in range(1,eband.shape[1]):
    plt.plot(eband[:,ib,0],color='blue',alpha=0.6)
    plt.plot(eband[:,ib,1],color='red',alpha=0.6)
plt.legend()
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('Si_VASP_nspin2.png',bbox_inches='tight')

# %% [markdown]
# # Example02: Pt (with SOC)

# %%
outdir = './example02/output/'
paoflow = PAOFLOW(savedir='./example02/nscf/',
                  outputdir=outdir, 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Fm-3m (225)
# Insulator: False
# Magnetic: False
# Number of kpoints: 72
# Number of electrons: 10.000000
# Number of bands: 20
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.13 GBytes
#
# Initialization in:                          0.032 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Pt':['5D','6S','6P','7S','7P']}
paoflow.projections(basispath=basis_path, configuration=basis_config)  # "internal=True" is optional, always use internal basis when dft == 'VASP'
# Out:
# atom: Pt  AEWFC: ../../BASIS/Pt\5D.dat           tau: [0. 0. 0.]
# atom: Pt  AEWFC: ../../BASIS/Pt\6S.dat           tau: [0. 0. 0.]
# atom: Pt  AEWFC: ../../BASIS/Pt\6P.dat           tau: [0. 0. 0.]
# atom: Pt  AEWFC: ../../BASIS/Pt\7S.dat           tau: [0. 0. 0.]
# atom: Pt  AEWFC: ../../BASIS/Pt\7P.dat           tau: [0. 0. 0.]
#       atwfc:   1  5D  l=2, m=1
#       atwfc:   2  5D  l=2, m=2
#       atwfc:   3  5D  l=2, m=3
#       atwfc:   4  5D  l=2, m=4
#       atwfc:   5  5D  l=2, m=5
#       atwfc:   6  5D  l=2, m=1
#       atwfc:   7  5D  l=2, m=2
#       atwfc:   8  5D  l=2, m=3
#       atwfc:   9  5D  l=2, m=4
#       atwfc:  10  5D  l=2, m=5
#       atwfc:  11  6S  l=0, m=1
#       atwfc:  12  6S  l=0, m=1
#       atwfc:  13  6P  l=1, m=1
#       atwfc:  14  6P  l=1, m=2
#       atwfc:  15  6P  l=1, m=3
#       atwfc:  16  6P  l=1, m=1
#       atwfc:  17  6P  l=1, m=2
#       atwfc:  18  6P  l=1, m=3
#       atwfc:  19  7S  l=0, m=1
#       atwfc:  20  7S  l=0, m=1
#       atwfc:  21  7P  l=1, m=1
#       atwfc:  22  7P  l=1, m=2
#       atwfc:  23  7P  l=1, m=3
#       atwfc:  24  7P  l=1, m=1
#       atwfc:  25  7P  l=1, m=2
#       atwfc:  26  7P  l=1, m=3
# Projections in:                             7.808 sec

# %%
paoflow.projectability()
# Out:
# Projectability vector  [0.98418964 0.98418828 0.96593671 0.96592066 0.96660345 0.96660519
#  0.95650462 0.9565008  0.9524204  0.95241346 0.95863714 0.95863476
#  0.85200682 0.85199256 0.66126058 0.6612731  0.71565118 0.71570637
#  0.43368345 0.43278206]
# # of bands with good projectability > 0.95 = 12
# Range of suggested shift  5.49489934  ,  16.76739934
# Projectability in:                          0.031 sec

# %%
paoflow.pao_hamiltonian(expand_wedge=True)
# Out:
# Building Hks in:                            1.092 sec
# k -> R in:                                  0.065 sec

# %%
paoflow.bands(ibrav=2,nk=500)
# Out:
# Bands in:                                   0.530 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
for ib in range(eband.shape[1]):
    plt.plot(eband[:,ib],color='black')
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()

# %%
paoflow.interpolated_hamiltonian()
paoflow.pao_eigh()
paoflow.gradient_and_momenta()
paoflow.adaptive_smearing(smearing='m-p')
# Out:
# Performing Fourier interpolation on a larger grid.
# d : nk -> nfft
# 1 : 12 -> 24
# 2 : 12 -> 24
# 3 : 12 -> 24
# New estimated maximum array size: 1.79 GBytes
# R -> k with Zero Padding in:                0.934 sec
# Eigenvalues in:                            10.271 sec
# Gradient in:                                2.870 sec
# Momenta in:                                 9.917 sec
# Adaptive Smearing in:                       1.248 sec

# %%
paoflow.spin_Hall(emin=-8., emax=4., s_tensor=[[0,1,2]])
# Out:
# Writing bxsf files for Spin Berry Curvature
# Spin Hall Conductivity in:                 16.125 sec

# %%
shc = np.loadtxt(outdir+'shcEf_z_xy.dat') 
fig = plt.figure(figsize=(4,3))
plt.plot(shc[:,0],shc[:,1],color='black')
plt.xlabel("E (eV)")
plt.ylabel("SHC_xy")
plt.xlim([-8,4])
plt.axhline(0,color='k',linewidth=0.5)
plt.show()

# %% [markdown]
# # Example03: Fe (with SOC, FM)

# %%
outdir = './example03/output/'
paoflow = PAOFLOW(savedir='./example03/nscf/',
                  outputdir=outdir, 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Im-3m (229)
# Insulator: False
# Magnetic: True
# Number of kpoints: 242
# Number of electrons: 8.000000
# Number of bands: 20
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.13 GBytes
#
# Initialization in:                          0.030 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Fe':['3D','4S','4P','4D','5S','5P']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Fe  AEWFC: ../../BASIS/Fe\3D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4P.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5P.dat           tau: [0. 0. 0.]
#       atwfc:   1  3D  l=2, m=1
#       atwfc:   2  3D  l=2, m=2
#       atwfc:   3  3D  l=2, m=3
#       atwfc:   4  3D  l=2, m=4
#       atwfc:   5  3D  l=2, m=5
#       atwfc:   6  3D  l=2, m=1
#       atwfc:   7  3D  l=2, m=2
#       atwfc:   8  3D  l=2, m=3
#       atwfc:   9  3D  l=2, m=4
#       atwfc:  10  3D  l=2, m=5
#       atwfc:  11  4S  l=0, m=1
#       atwfc:  12  4S  l=0, m=1
#       atwfc:  13  4P  l=1, m=1
#       atwfc:  14  4P  l=1, m=2
#       atwfc:  15  4P  l=1, m=3
#       atwfc:  16  4P  l=1, m=1
#       atwfc:  17  4P  l=1, m=2
#       atwfc:  18  4P  l=1, m=3
#       atwfc:  19  4D  l=2, m=1
#       atwfc:  20  4D  l=2, m=2
#       atwfc:  21  4D  l=2, m=3
#       atwfc:  22  4D  l=2, m=4
#       atwfc:  23  4D  l=2, m=5
#       atwfc:  24  4D  l=2, m=1
#       atwfc:  25  4D  l=2, m=2
#       atwfc:  26  4D  l=2, m=3
#       atwfc:  27  4D  l=2, m=4
#       atwfc:  28  4D  l=2, m=5
#       atwfc:  29  5S  l=0, m=1
#       atwfc:  30  5S  l=0, m=1
#       atwfc:  31  5P  l=1, m=1
#       atwfc:  32  5P  l=1, m=2
#       atwfc:  33  5P  l=1, m=3
#       atwfc:  34  5P  l=1, m=1
#       atwfc:  35  5P  l=1, m=2
#       atwfc:  36  5P  l=1, m=3
# Projections in:                            18.089 sec

# %%
paoflow.projectability(pthr=0.90)
# Out:
# Projectability vector  [0.9288716  0.92914785 0.91476342 0.91681965 0.90542112 0.90109328
#  0.90971065 0.91046696 0.89244272 0.90559374 0.91714585 0.89113578
#  0.90838498 0.89608389 0.88356118 0.87224313 0.85553157 0.85226032
#  0.44201382 0.43591139]
# # of bands with good projectability > 0.9 = 11
# Range of suggested shift  1.5359874600000003  ,  9.851387460000002
# Projectability in:                          0.019 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            0.867 sec
# k -> R in:                                  0.122 sec

# %%
paoflow.bands(ibrav=3,nk=500)
# Out:
# Bands in:                                   0.547 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
plt.plot(eband[:,0],color='black')
for ib in range(1,eband.shape[1]):
    plt.plot(eband[:,ib],color='black')
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('Fe_VASP.png',bbox_inches='tight')

# %%
paoflow.interpolated_hamiltonian()
paoflow.pao_eigh()
paoflow.gradient_and_momenta()
paoflow.adaptive_smearing(smearing='m-p')
# Out:
# Performing Fourier interpolation on a larger grid.
# d : nk -> nfft
# 1 : 12 -> 24
# 2 : 12 -> 24
# 3 : 12 -> 24
# New estimated maximum array size: 3.44 GBytes
# R -> k with Zero Padding in:                1.571 sec
# Eigenvalues in:                             5.421 sec
# Gradient in:                                6.026 sec
# Momenta in:                                30.291 sec
# Adaptive Smearing in:                       2.160 sec

# %%
paoflow.anomalous_Hall(do_ac=True, emin=-6., emax=1., a_tensor=np.array([[0,1]]))
# Out:
# Writing bxsf files for Berry Curvature
# Anomalous Hall Conductivity in:           487.223 sec

# %%
ahc = np.loadtxt(outdir+'ahcEf_xy.dat')
fig = plt.figure(figsize=(4,3))
plt.xlabel("E (eV)")
plt.ylabel("AHC_xy")
plt.plot(ahc[:,0],ahc[:,1],color='black')
plt.xlim([-6,1])
plt.axhline(0,color='k',linewidth=0.5)
plt.show()

# %% [markdown]
# # Example04: MnF2 (nspin=2, collinear AFM)

# %%
paoflow = PAOFLOW(savedir='./example04/nscf/',
                  outputdir='./example04/output/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 8 8 12 0 0 0
# Space group: P4_2/mnm (136)
# Insulator: True
# Magnetic: True
# Number of kpoints: 105
# Number of electrons: 42.000000
# Number of bands: 36
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.38 GBytes
#
# Initialization in:                          0.066 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Mn':['3P','3D','4S','4P','4D','4F'],
                'F':['2P','3S','3P','3D','4S']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Mn  AEWFC: ../../BASIS/Mn\3P.dat           tau: [0. 0. 0.]
# atom: Mn  AEWFC: ../../BASIS/Mn\3D.dat           tau: [0. 0. 0.]
# atom: Mn  AEWFC: ../../BASIS/Mn\4S.dat           tau: [0. 0. 0.]
# atom: Mn  AEWFC: ../../BASIS/Mn\4P.dat           tau: [0. 0. 0.]
# atom: Mn  AEWFC: ../../BASIS/Mn\4D.dat           tau: [0. 0. 0.]
# atom: Mn  AEWFC: ../../BASIS/Mn\4F.dat           tau: [0. 0. 0.]
#       atwfc:   1  3P  l=1, m=1
#       atwfc:   2  3P  l=1, m=2
#       atwfc:   3  3P  l=1, m=3
#       atwfc:   4  3D  l=2, m=1
#       atwfc:   5  3D  l=2, m=2
#       atwfc:   6  3D  l=2, m=3
#       atwfc:   7  3D  l=2, m=4
#       atwfc:   8  3D  l=2, m=5
#       atwfc:   9  4S  l=0, m=1
#       atwfc:  10  4P  l=1, m=1
#       atwfc:  11  4P  l=1, m=2
#       atwfc:  12  4P  l=1, m=3
#       atwfc:  13  4D  l=2, m=1
#       atwfc:  14  4D  l=2, m=2
#       atwfc:  15  4D  l=2, m=3
#       atwfc:  16  4D  l=2, m=4
#       atwfc:  17  4D  l=2, m=5
#       atwfc:  18  4F  l=3, m=1
#       atwfc:  19  4F  l=3, m=2
#       atwfc:  20  4F  l=3, m=3
#       atwfc:  21  4F  l=3, m=4
#       atwfc:  22  4F  l=3, m=5
#       atwfc:  23  4F  l=3, m=6
#       atwfc:  24  4F  l=3, m=7
# atom: Mn  AEWFC: ../../BASIS/Mn\3P.dat           tau: [4.68219993 4.68219993 3.15297726]
# atom: Mn  AEWFC: ../../BASIS/Mn\3D.dat           tau: [4.68219993 4.68219993 3.15297726]
# atom: Mn  AEWFC: ../../BASIS/Mn\4S.dat           tau: [4.68219993 4.68219993 3.15297726]
# atom: Mn  AEWFC: ../../BASIS/Mn\4P.dat           tau: [4.68219993 4.68219993 3.15297726]
# atom: Mn  AEWFC: ../../BASIS/Mn\4D.dat           tau: [4.68219993 4.68219993 3.15297726]
# atom: Mn  AEWFC: ../../BASIS/Mn\4F.dat           tau: [4.68219993 4.68219993 3.15297726]
#       atwfc:  25  3P  l=1, m=1
#       atwfc:  26  3P  l=1, m=2
#       atwfc:  27  3P  l=1, m=3
#       atwfc:  28  3D  l=2, m=1
#       atwfc:  29  3D  l=2, m=2
#       atwfc:  30  3D  l=2, m=3
#       atwfc:  31  3D  l=2, m=4
#       atwfc:  32  3D  l=2, m=5
#       atwfc:  33  4S  l=0, m=1
#       atwfc:  34  4P  l=1, m=1
#       atwfc:  35  4P  l=1, m=2
#       atwfc:  36  4P  l=1, m=3
#       atwfc:  37  4D  l=2, m=1
#       atwfc:  38  4D  l=2, m=2
#       atwfc:  39  4D  l=2, m=3
#       atwfc:  40  4D  l=2, m=4
#       atwfc:  41  4D  l=2, m=5
#       atwfc:  42  4F  l=3, m=1
#       atwfc:  43  4F  l=3, m=2
#       atwfc:  44  4F  l=3, m=3
#       atwfc:  45  4F  l=3, m=4
#       atwfc:  46  4F  l=3, m=5
#       atwfc:  47  4F  l=3, m=6
#       atwfc:  48  4F  l=3, m=7
# atom: F   AEWFC: ../../BASIS/F\2P.dat            tau: [2.85302792 2.85302792 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3S.dat            tau: [2.85302792 2.85302792 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3P.dat            tau: [2.85302792 2.85302792 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3D.dat            tau: [2.85302792 2.85302792 0.        ]
# atom: F   AEWFC: ../../BASIS/F\4S.dat            tau: [2.85302792 2.85302792 0.        ]
#       atwfc:  49  2P  l=1, m=1
#       atwfc:  50  2P  l=1, m=2
#       atwfc:  51  2P  l=1, m=3
#       atwfc:  52  3S  l=0, m=1
#       atwfc:  53  3P  l=1, m=1
#       atwfc:  54  3P  l=1, m=2
#       atwfc:  55  3P  l=1, m=3
#       atwfc:  56  3D  l=2, m=1
#       atwfc:  57  3D  l=2, m=2
#       atwfc:  58  3D  l=2, m=3
#       atwfc:  59  3D  l=2, m=4
#       atwfc:  60  3D  l=2, m=5
#       atwfc:  61  4S  l=0, m=1
# atom: F   AEWFC: ../../BASIS/F\2P.dat            tau: [6.51137194 6.51137194 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3S.dat            tau: [6.51137194 6.51137194 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3P.dat            tau: [6.51137194 6.51137194 0.        ]
# atom: F   AEWFC: ../../BASIS/F\3D.dat            tau: [6.51137194 6.51137194 0.        ]
# atom: F   AEWFC: ../../BASIS/F\4S.dat            tau: [6.51137194 6.51137194 0.        ]
#       atwfc:  62  2P  l=1, m=1
#       atwfc:  63  2P  l=1, m=2
#       atwfc:  64  2P  l=1, m=3
#       atwfc:  65  3S  l=0, m=1
#       atwfc:  66  3P  l=1, m=1
#       atwfc:  67  3P  l=1, m=2
#       atwfc:  68  3P  l=1, m=3
#       atwfc:  69  3D  l=2, m=1
#       atwfc:  70  3D  l=2, m=2
#       atwfc:  71  3D  l=2, m=3
#       atwfc:  72  3D  l=2, m=4
#       atwfc:  73  3D  l=2, m=5
#       atwfc:  74  4S  l=0, m=1
# atom: F   AEWFC: ../../BASIS/F\2P.dat            tau: [1.82917201 7.53522786 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3S.dat            tau: [1.82917201 7.53522786 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3P.dat            tau: [1.82917201 7.53522786 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3D.dat            tau: [1.82917201 7.53522786 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\4S.dat            tau: [1.82917201 7.53522786 3.15297726]
#       atwfc:  75  2P  l=1, m=1
#       atwfc:  76  2P  l=1, m=2
#       atwfc:  77  2P  l=1, m=3
#       atwfc:  78  3S  l=0, m=1
#       atwfc:  79  3P  l=1, m=1
#       atwfc:  80  3P  l=1, m=2
#       atwfc:  81  3P  l=1, m=3
#       atwfc:  82  3D  l=2, m=1
#       atwfc:  83  3D  l=2, m=2
#       atwfc:  84  3D  l=2, m=3
#       atwfc:  85  3D  l=2, m=4
#       atwfc:  86  3D  l=2, m=5
#       atwfc:  87  4S  l=0, m=1
# atom: F   AEWFC: ../../BASIS/F\2P.dat            tau: [7.53522786 1.82917201 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3S.dat            tau: [7.53522786 1.82917201 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3P.dat            tau: [7.53522786 1.82917201 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\3D.dat            tau: [7.53522786 1.82917201 3.15297726]
# atom: F   AEWFC: ../../BASIS/F\4S.dat            tau: [7.53522786 1.82917201 3.15297726]
#       atwfc:  88  2P  l=1, m=1
#       atwfc:  89  2P  l=1, m=2
#       atwfc:  90  2P  l=1, m=3
#       atwfc:  91  3S  l=0, m=1
#       atwfc:  92  3P  l=1, m=1
#       atwfc:  93  3P  l=1, m=2
#       atwfc:  94  3P  l=1, m=3
#       atwfc:  95  3D  l=2, m=1
#       atwfc:  96  3D  l=2, m=2
#       atwfc:  97  3D  l=2, m=3
#       atwfc:  98  3D  l=2, m=4
#       atwfc:  99  3D  l=2, m=5
#       atwfc: 100  4S  l=0, m=1
# Projections in:                           110.165 sec

# %%
paoflow.projectability(pthr=0.90)
# Out:
# Projectability vector  [0.96253166 0.96427115 0.96451708 0.96464321 0.95682998 0.95627354
#  0.94922616 0.95122929 0.95096439 0.95578937 0.95714422 0.95895593
#  0.95292168 0.95783611 0.95822169 0.95670986 0.87776659 0.88338878
#  0.88122898 0.86735517 0.87691689 0.93081204 0.90998563 0.90533025
#  0.90163643 0.88835973 0.91975827 0.96576968 0.97705995 0.97674761
#  0.9754993  0.97587228 0.97692308 0.97794291 0.97588859 0.97459249]
# # of bands with good projectability > 0.9 = 30
# Range of suggested shift  10.672977399999999  ,  14.344577399999999
# Projectability in:                          0.038 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            3.763 sec
# k -> R in:                                  0.925 sec

# %%
paoflow.bands(ibrav=6,nk=500)
# Out:
# Bands in:                                  13.716 sec

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,3))
# plot the paoflow bands (all bands and bands near Fermi energy)
eband = arry['E_k']
ax[0].plot(eband[:,0,0],color='red',alpha=0.6,label="up")
ax[0].plot(eband[:,0,1],color='blue',alpha=0.6,label="down")
for ib in range(1,eband.shape[1]):
    ax[0].plot(eband[:,ib,0],color='red',alpha=0.6)
    ax[0].plot(eband[:,ib,1],color='blue',alpha=0.6)
    ax[1].plot(eband[:,ib,0],color='red',alpha=0.6)
    ax[1].plot(eband[:,ib,1],color='blue',alpha=0.6)
ax[1].set_ylim([-1,0.2])
ax[0].set_xlim([0,eband.shape[0]-1])
ax[1].set_xlim([0,eband.shape[0]-1])
ax[0].set_ylabel("E (eV)")
ax[0].legend()
plt.show()
# plt.savefig('MnF2_VASP.png',bbox_inches='tight')

# %% [markdown]
# # Example05: Mn3Ir (with SOC, noncollinear 120$^\circ$ AFM)

# %%
paoflow = PAOFLOW(savedir='./example05/nscf/',
                  outputdir='./example05/output/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 10 10 10 0 0 0
# Space group: Pm-3m (221)
# Insulator: False
# Magnetic: True
# Number of kpoints: 172
# Number of electrons: 30.000000
# Number of bands: 40
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.31 GBytes
#
# Initialization in:                          0.177 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Ir':['5P','5D','6S','6P','7S'],
                'Mn':['3P','3D','4S','4P','4D']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Ir  AEWFC: ../../BASIS/Ir\5P.dat           tau: [0. 0. 0.]
# atom: Ir  AEWFC: ../../BASIS/Ir\5D.dat           tau: [0. 0. 0.]
# atom: Ir  AEWFC: ../../BASIS/Ir\6S.dat           tau: [0. 0. 0.]
# atom: Ir  AEWFC: ../../BASIS/Ir\6P.dat           tau: [0. 0. 0.]
# atom: Ir  AEWFC: ../../BASIS/Ir\7S.dat           tau: [0. 0. 0.]
#       atwfc:   1  5P  l=1, m=1
#       atwfc:   2  5P  l=1, m=2
#       atwfc:   3  5P  l=1, m=3
#       atwfc:   4  5P  l=1, m=1
#       atwfc:   5  5P  l=1, m=2
#       atwfc:   6  5P  l=1, m=3
#       atwfc:   7  5D  l=2, m=1
#       atwfc:   8  5D  l=2, m=2
#       atwfc:   9  5D  l=2, m=3
#       atwfc:  10  5D  l=2, m=4
#       atwfc:  11  5D  l=2, m=5
#       atwfc:  12  5D  l=2, m=1
#       atwfc:  13  5D  l=2, m=2
#       atwfc:  14  5D  l=2, m=3
#       atwfc:  15  5D  l=2, m=4
#       atwfc:  16  5D  l=2, m=5
#       atwfc:  17  6S  l=0, m=1
#       atwfc:  18  6S  l=0, m=1
#       atwfc:  19  6P  l=1, m=1
#       atwfc:  20  6P  l=1, m=2
#       atwfc:  21  6P  l=1, m=3
#       atwfc:  22  6P  l=1, m=1
#       atwfc:  23  6P  l=1, m=2
#       atwfc:  24  6P  l=1, m=3
#       atwfc:  25  7S  l=0, m=1
#       atwfc:  26  7S  l=0, m=1
# atom: Mn  AEWFC: ../../BASIS/Mn\3P.dat           tau: [0.         3.56213349 3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\3D.dat           tau: [0.         3.56213349 3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4S.dat           tau: [0.         3.56213349 3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4P.dat           tau: [0.         3.56213349 3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4D.dat           tau: [0.         3.56213349 3.56213349]
#       atwfc:  27  3P  l=1, m=1
#       atwfc:  28  3P  l=1, m=2
#       atwfc:  29  3P  l=1, m=3
#       atwfc:  30  3P  l=1, m=1
#       atwfc:  31  3P  l=1, m=2
#       atwfc:  32  3P  l=1, m=3
#       atwfc:  33  3D  l=2, m=1
#       atwfc:  34  3D  l=2, m=2
#       atwfc:  35  3D  l=2, m=3
#       atwfc:  36  3D  l=2, m=4
#       atwfc:  37  3D  l=2, m=5
#       atwfc:  38  3D  l=2, m=1
#       atwfc:  39  3D  l=2, m=2
#       atwfc:  40  3D  l=2, m=3
#       atwfc:  41  3D  l=2, m=4
#       atwfc:  42  3D  l=2, m=5
#       atwfc:  43  4S  l=0, m=1
#       atwfc:  44  4S  l=0, m=1
#       atwfc:  45  4P  l=1, m=1
#       atwfc:  46  4P  l=1, m=2
#       atwfc:  47  4P  l=1, m=3
#       atwfc:  48  4P  l=1, m=1
#       atwfc:  49  4P  l=1, m=2
#       atwfc:  50  4P  l=1, m=3
#       atwfc:  51  4D  l=2, m=1
#       atwfc:  52  4D  l=2, m=2
#       atwfc:  53  4D  l=2, m=3
#       atwfc:  54  4D  l=2, m=4
#       atwfc:  55  4D  l=2, m=5
#       atwfc:  56  4D  l=2, m=1
#       atwfc:  57  4D  l=2, m=2
#       atwfc:  58  4D  l=2, m=3
#       atwfc:  59  4D  l=2, m=4
#       atwfc:  60  4D  l=2, m=5
# atom: Mn  AEWFC: ../../BASIS/Mn\3P.dat           tau: [3.56213349 0.         3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\3D.dat           tau: [3.56213349 0.         3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4S.dat           tau: [3.56213349 0.         3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4P.dat           tau: [3.56213349 0.         3.56213349]
# atom: Mn  AEWFC: ../../BASIS/Mn\4D.dat           tau: [3.56213349 0.         3.56213349]
#       atwfc:  61  3P  l=1, m=1
#       atwfc:  62  3P  l=1, m=2
#       atwfc:  63  3P  l=1, m=3
#       atwfc:  64  3P  l=1, m=1
#       atwfc:  65  3P  l=1, m=2
#       atwfc:  66  3P  l=1, m=3
#       atwfc:  67  3D  l=2, m=1
#       atwfc:  68  3D  l=2, m=2
#       atwfc:  69  3D  l=2, m=3
#       atwfc:  70  3D  l=2, m=4
#       atwfc:  71  3D  l=2, m=5
#       atwfc:  72  3D  l=2, m=1
#       atwfc:  73  3D  l=2, m=2
#       atwfc:  74  3D  l=2, m=3
#       atwfc:  75  3D  l=2, m=4
#       atwfc:  76  3D  l=2, m=5
#       atwfc:  77  4S  l=0, m=1
#       atwfc:  78  4S  l=0, m=1
#       atwfc:  79  4P  l=1, m=1
#       atwfc:  80  4P  l=1, m=2
#       atwfc:  81  4P  l=1, m=3
#       atwfc:  82  4P  l=1, m=1
#       atwfc:  83  4P  l=1, m=2
#       atwfc:  84  4P  l=1, m=3
#       atwfc:  85  4D  l=2, m=1
#       atwfc:  86  4D  l=2, m=2
#       atwfc:  87  4D  l=2, m=3
#       atwfc:  88  4D  l=2, m=4
#       atwfc:  89  4D  l=2, m=5
#       atwfc:  90  4D  l=2, m=1
#       atwfc:  91  4D  l=2, m=2
#       atwfc:  92  4D  l=2, m=3
#       atwfc:  93  4D  l=2, m=4
#       atwfc:  94  4D  l=2, m=5
# atom: Mn  AEWFC: ../../BASIS/Mn\3P.dat           tau: [3.56213349 3.56213349 0.        ]
# atom: Mn  AEWFC: ../../BASIS/Mn\3D.dat           tau: [3.56213349 3.56213349 0.        ]
# atom: Mn  AEWFC: ../../BASIS/Mn\4S.dat           tau: [3.56213349 3.56213349 0.        ]
# atom: Mn  AEWFC: ../../BASIS/Mn\4P.dat           tau: [3.56213349 3.56213349 0.        ]
# atom: Mn  AEWFC: ../../BASIS/Mn\4D.dat           tau: [3.56213349 3.56213349 0.        ]
#       atwfc:  95  3P  l=1, m=1
#       atwfc:  96  3P  l=1, m=2
#       atwfc:  97  3P  l=1, m=3
#       atwfc:  98  3P  l=1, m=1
#       atwfc:  99  3P  l=1, m=2
#       atwfc: 100  3P  l=1, m=3
#       atwfc: 101  3D  l=2, m=1
#       atwfc: 102  3D  l=2, m=2
#       atwfc: 103  3D  l=2, m=3
#       atwfc: 104  3D  l=2, m=4
#       atwfc: 105  3D  l=2, m=5
#       atwfc: 106  3D  l=2, m=1
#       atwfc: 107  3D  l=2, m=2
#       atwfc: 108  3D  l=2, m=3
#       atwfc: 109  3D  l=2, m=4
#       atwfc: 110  3D  l=2, m=5
#       atwfc: 111  4S  l=0, m=1
#       atwfc: 112  4S  l=0, m=1
#       atwfc: 113  4P  l=1, m=1
#       atwfc: 114  4P  l=1, m=2
#       atwfc: 115  4P  l=1, m=3
#       atwfc: 116  4P  l=1, m=1
#       atwfc: 117  4P  l=1, m=2
#       atwfc: 118  4P  l=1, m=3
#       atwfc: 119  4D  l=2, m=1
#       atwfc: 120  4D  l=2, m=2
#       atwfc: 121  4D  l=2, m=3
#       atwfc: 122  4D  l=2, m=4
#       atwfc: 123  4D  l=2, m=5
#       atwfc: 124  4D  l=2, m=1
#       atwfc: 125  4D  l=2, m=2
#       atwfc: 126  4D  l=2, m=3
#       atwfc: 127  4D  l=2, m=4
#       atwfc: 128  4D  l=2, m=5
# Projections in:                            90.453 sec

# %%
paoflow.projectability(pthr=0.90)
# Out:
# Projectability vector  [0.98972321 0.99002268 0.96977821 0.97303032 0.96688848 0.97090448
#  0.96366766 0.96860099 0.96360712 0.96306746 0.96006424 0.95661519
#  0.95616507 0.95211964 0.94350014 0.93998837 0.93672238 0.93483027
#  0.93393717 0.91959913 0.92220855 0.91480924 0.91701221 0.9180249
#  0.92349146 0.9255495  0.9253709  0.93570626 0.94056335 0.94049338
#  0.93148843 0.9271042  0.92476301 0.91049252 0.90692693 0.90783239
#  0.90973202 0.90751186 0.90805019 0.90523427]
# WARNING: All bands meet the projectability threshold. Consider increasing number of bands.
# # of bands with good projectability > 0.9 = 40
# Projectability in:                          0.045 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            2.826 sec
# k -> R in:                                  1.027 sec

# %%
paoflow.bands(ibrav=1,nk=500)
# Out:
# Bands in:                                  14.056 sec

# %%
fig = plt.figure(figsize=(6,4))
# plot the paoflow bands
eband = arry['E_k']
for ib in range(eband.shape[1]):
    plt.plot(eband[:,ib],color='black')
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('Mn3Ir_VASP.png',bbox_inches='tight')

# %% [markdown]
# # Example06: FeRh (with SOC, FM)

# %%
paoflow = PAOFLOW(savedir='./example06/nscf_soc/',
                  outputdir='./example06/output_soc/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Pm-3m (221)
# Insulator: False
# Magnetic: True
# Number of kpoints: 266
# Number of electrons: 17.000000
# Number of bands: 32
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.34 GBytes
#
# Initialization in:                          0.089 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Fe':['3D','4S','4P','4D','5S','5P'],
                'Rh':['4D','4F','5S','5P','5D']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Fe  AEWFC: ../../BASIS/Fe\3D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4P.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5P.dat           tau: [0. 0. 0.]
#       atwfc:   1  3D  l=2, m=1
#       atwfc:   2  3D  l=2, m=2
#       atwfc:   3  3D  l=2, m=3
#       atwfc:   4  3D  l=2, m=4
#       atwfc:   5  3D  l=2, m=5
#       atwfc:   6  3D  l=2, m=1
#       atwfc:   7  3D  l=2, m=2
#       atwfc:   8  3D  l=2, m=3
#       atwfc:   9  3D  l=2, m=4
#       atwfc:  10  3D  l=2, m=5
#       atwfc:  11  4S  l=0, m=1
#       atwfc:  12  4S  l=0, m=1
#       atwfc:  13  4P  l=1, m=1
#       atwfc:  14  4P  l=1, m=2
#       atwfc:  15  4P  l=1, m=3
#       atwfc:  16  4P  l=1, m=1
#       atwfc:  17  4P  l=1, m=2
#       atwfc:  18  4P  l=1, m=3
#       atwfc:  19  4D  l=2, m=1
#       atwfc:  20  4D  l=2, m=2
#       atwfc:  21  4D  l=2, m=3
#       atwfc:  22  4D  l=2, m=4
#       atwfc:  23  4D  l=2, m=5
#       atwfc:  24  4D  l=2, m=1
#       atwfc:  25  4D  l=2, m=2
#       atwfc:  26  4D  l=2, m=3
#       atwfc:  27  4D  l=2, m=4
#       atwfc:  28  4D  l=2, m=5
#       atwfc:  29  5S  l=0, m=1
#       atwfc:  30  5S  l=0, m=1
#       atwfc:  31  5P  l=1, m=1
#       atwfc:  32  5P  l=1, m=2
#       atwfc:  33  5P  l=1, m=3
#       atwfc:  34  5P  l=1, m=1
#       atwfc:  35  5P  l=1, m=2
#       atwfc:  36  5P  l=1, m=3
# atom: Rh  AEWFC: ../../BASIS/Rh\4D.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\4F.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5S.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5P.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5D.dat           tau: [2.83458898 2.83458898 2.83458898]
#       atwfc:  37  4D  l=2, m=1
#       atwfc:  38  4D  l=2, m=2
#       atwfc:  39  4D  l=2, m=3
#       atwfc:  40  4D  l=2, m=4
#       atwfc:  41  4D  l=2, m=5
#       atwfc:  42  4D  l=2, m=1
#       atwfc:  43  4D  l=2, m=2
#       atwfc:  44  4D  l=2, m=3
#       atwfc:  45  4D  l=2, m=4
#       atwfc:  46  4D  l=2, m=5
#       atwfc:  47  4F  l=3, m=1
#       atwfc:  48  4F  l=3, m=2
#       atwfc:  49  4F  l=3, m=3
#       atwfc:  50  4F  l=3, m=4
#       atwfc:  51  4F  l=3, m=5
#       atwfc:  52  4F  l=3, m=6
#       atwfc:  53  4F  l=3, m=7
#       atwfc:  54  4F  l=3, m=1
#       atwfc:  55  4F  l=3, m=2
#       atwfc:  56  4F  l=3, m=3
#       atwfc:  57  4F  l=3, m=4
#       atwfc:  58  4F  l=3, m=5
#       atwfc:  59  4F  l=3, m=6
#       atwfc:  60  4F  l=3, m=7
#       atwfc:  61  5S  l=0, m=1
#       atwfc:  62  5S  l=0, m=1
#       atwfc:  63  5P  l=1, m=1
#       atwfc:  64  5P  l=1, m=2
#       atwfc:  65  5P  l=1, m=3
#       atwfc:  66  5P  l=1, m=1
#       atwfc:  67  5P  l=1, m=2
#       atwfc:  68  5P  l=1, m=3
#       atwfc:  69  5D  l=2, m=1
#       atwfc:  70  5D  l=2, m=2
#       atwfc:  71  5D  l=2, m=3
#       atwfc:  72  5D  l=2, m=4
#       atwfc:  73  5D  l=2, m=5
#       atwfc:  74  5D  l=2, m=1
#       atwfc:  75  5D  l=2, m=2
#       atwfc:  76  5D  l=2, m=3
#       atwfc:  77  5D  l=2, m=4
#       atwfc:  78  5D  l=2, m=5
# Projections in:                            55.968 sec

# %%
paoflow.projectability(pthr=0.90)
# Out:
# Projectability vector  [0.96942104 0.95012422 0.94721949 0.93614589 0.92500425 0.93308848
#  0.92539861 0.93194486 0.92560881 0.919522   0.92342568 0.92018536
#  0.91953167 0.9290087  0.93485859 0.93038732 0.91656053 0.9005916
#  0.89937441 0.92787386 0.92883853 0.91829894 0.94838986 0.93695376
#  0.96700363 0.96297985 0.96496881 0.96240984 0.95714788 0.93836192
#  0.91746191 0.91972833]
# # of bands with good projectability > 0.9 = 31
# Range of suggested shift  9.860800900000001  ,  17.2602009
# Projectability in:                          0.050 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            2.508 sec
# k -> R in:                                  0.522 sec

# %%
paoflow.bands(ibrav=1,nk=500)
# Out:
# Bands in:                                   3.979 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
for ib in range(eband.shape[1]):
    plt.plot(eband[:,ib],color='black')
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('FeRh_VASP.png',bbox_inches='tight')

# %% [markdown]
#  # Example06: FeRh (nspin = 2, FM)

# %%
paoflow = PAOFLOW(savedir='./example06/nscf_nspin2/',
                  outputdir='./example06/output_nspin2/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 12 12 12 0 0 0
# Space group: Pm-3m (221)
# Insulator: False
# Magnetic: True
# Number of kpoints: 84
# Number of electrons: 17.000000
# Number of bands: 16
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.17 GBytes
#
# Initialization in:                          0.025 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Fe':['3D','4S','4P','4D','5S','5P'],
                'Rh':['4D','4F','5S','5P','5D']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Fe  AEWFC: ../../BASIS/Fe\3D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4P.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\4D.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5S.dat           tau: [0. 0. 0.]
# atom: Fe  AEWFC: ../../BASIS/Fe\5P.dat           tau: [0. 0. 0.]
#       atwfc:   1  3D  l=2, m=1
#       atwfc:   2  3D  l=2, m=2
#       atwfc:   3  3D  l=2, m=3
#       atwfc:   4  3D  l=2, m=4
#       atwfc:   5  3D  l=2, m=5
#       atwfc:   6  4S  l=0, m=1
#       atwfc:   7  4P  l=1, m=1
#       atwfc:   8  4P  l=1, m=2
#       atwfc:   9  4P  l=1, m=3
#       atwfc:  10  4D  l=2, m=1
#       atwfc:  11  4D  l=2, m=2
#       atwfc:  12  4D  l=2, m=3
#       atwfc:  13  4D  l=2, m=4
#       atwfc:  14  4D  l=2, m=5
#       atwfc:  15  5S  l=0, m=1
#       atwfc:  16  5P  l=1, m=1
#       atwfc:  17  5P  l=1, m=2
#       atwfc:  18  5P  l=1, m=3
# atom: Rh  AEWFC: ../../BASIS/Rh\4D.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\4F.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5S.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5P.dat           tau: [2.83458898 2.83458898 2.83458898]
# atom: Rh  AEWFC: ../../BASIS/Rh\5D.dat           tau: [2.83458898 2.83458898 2.83458898]
#       atwfc:  19  4D  l=2, m=1
#       atwfc:  20  4D  l=2, m=2
#       atwfc:  21  4D  l=2, m=3
#       atwfc:  22  4D  l=2, m=4
#       atwfc:  23  4D  l=2, m=5
#       atwfc:  24  4F  l=3, m=1
#       atwfc:  25  4F  l=3, m=2
#       atwfc:  26  4F  l=3, m=3
#       atwfc:  27  4F  l=3, m=4
#       atwfc:  28  4F  l=3, m=5
#       atwfc:  29  4F  l=3, m=6
#       atwfc:  30  4F  l=3, m=7
#       atwfc:  31  5S  l=0, m=1
#       atwfc:  32  5P  l=1, m=1
#       atwfc:  33  5P  l=1, m=2
#       atwfc:  34  5P  l=1, m=3
#       atwfc:  35  5D  l=2, m=1
#       atwfc:  36  5D  l=2, m=2
#       atwfc:  37  5D  l=2, m=3
#       atwfc:  38  5D  l=2, m=4
#       atwfc:  39  5D  l=2, m=5
# Projections in:                            19.626 sec

# %%
paoflow.projectability(pthr=0.90)
# Out:
# Projectability vector  [0.97354572 0.93727849 0.94139393 0.91955077 0.92816319 0.92584235
#  0.90100264 0.90976305 0.92603481 0.92963779 0.92372953 0.94915393
#  0.96332228 0.96645518 0.95149576 0.91308933]
# WARNING: All bands meet the projectability threshold. Consider increasing number of bands.
# # of bands with good projectability > 0.9 = 16
# Projectability in:                          0.035 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            2.946 sec
# k -> R in:                                  0.337 sec

# %%
paoflow.bands(ibrav=1,nk=500)
# Out:
# Bands in:                                   1.867 sec

# %%
fig = plt.figure(figsize=(6,4))
eband = arry['E_k']
plt.plot(eband[:,0,0],color='red',alpha=0.6,label="up")
plt.plot(eband[:,0,1],color='blue',alpha=0.6,label="down")
for ib in range(1,eband.shape[1]):
    plt.plot(eband[:,ib,0],color='blue',alpha=0.6)
    plt.plot(eband[:,ib,1],color='red',alpha=0.6)
plt.legend()
plt.xlim([0,eband.shape[0]-1])
plt.ylabel("E (eV)")
plt.show()
# plt.savefig('FeRh_nspin2_VASP.png',bbox_inches='tight')

# %% [markdown]
# # Example 07: CrI3 monolayer (nspin = 2, FM)

# %%
paoflow = PAOFLOW(savedir='./example07/nscf_nspin2/',  
                  outputdir='./example07/output_nspin2/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow.data_controller
arry,attr = paoflow.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 10 10 1 0 0 0
# Space group: P-31m (162)
# Insulator: True
# Magnetic: True
# Number of kpoints: 14
# Number of electrons: 54.000000
# Number of bands: 40
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.06 GBytes
#
# Initialization in:                          0.124 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Cr':['3D','4S','4P','4D','5S','5P','5D'],
                'I':['5S','5P','5D','6S','6P','4F']}
paoflow.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Cr  AEWFC: ../../BASIS/Cr\3D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4S.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4P.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5S.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5P.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
#       atwfc:   1  3D  l=2, m=1
#       atwfc:   2  3D  l=2, m=2
#       atwfc:   3  3D  l=2, m=3
#       atwfc:   4  3D  l=2, m=4
#       atwfc:   5  3D  l=2, m=5
#       atwfc:   6  4S  l=0, m=1
#       atwfc:   7  4P  l=1, m=1
#       atwfc:   8  4P  l=1, m=2
#       atwfc:   9  4P  l=1, m=3
#       atwfc:  10  4D  l=2, m=1
#       atwfc:  11  4D  l=2, m=2
#       atwfc:  12  4D  l=2, m=3
#       atwfc:  13  4D  l=2, m=4
#       atwfc:  14  4D  l=2, m=5
#       atwfc:  15  5S  l=0, m=1
#       atwfc:  16  5P  l=1, m=1
#       atwfc:  17  5P  l=1, m=2
#       atwfc:  18  5P  l=1, m=3
#       atwfc:  19  5D  l=2, m=1
#       atwfc:  20  5D  l=2, m=2
#       atwfc:  21  5D  l=2, m=3
#       atwfc:  22  5D  l=2, m=4
#       atwfc:  23  5D  l=2, m=5
# atom: Cr  AEWFC: ../../BASIS/Cr\3D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4S.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4P.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5S.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5P.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
#       atwfc:  24  3D  l=2, m=1
#       atwfc:  25  3D  l=2, m=2
#       atwfc:  26  3D  l=2, m=3
#       atwfc:  27  3D  l=2, m=4
#       atwfc:  28  3D  l=2, m=5
#       atwfc:  29  4S  l=0, m=1
#       atwfc:  30  4P  l=1, m=1
#       atwfc:  31  4P  l=1, m=2
#       atwfc:  32  4P  l=1, m=3
#       atwfc:  33  4D  l=2, m=1
#       atwfc:  34  4D  l=2, m=2
#       atwfc:  35  4D  l=2, m=3
#       atwfc:  36  4D  l=2, m=4
#       atwfc:  37  4D  l=2, m=5
#       atwfc:  38  5S  l=0, m=1
#       atwfc:  39  5P  l=1, m=1
#       atwfc:  40  5P  l=1, m=2
#       atwfc:  41  5P  l=1, m=3
#       atwfc:  42  5D  l=2, m=1
#       atwfc:  43  5D  l=2, m=2
#       atwfc:  44  5D  l=2, m=3
#       atwfc:  45  5D  l=2, m=4
#       atwfc:  46  5D  l=2, m=5
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 1.91342204 11.46883288 14.05033278]
#       atwfc:  47  5S  l=0, m=1
#       atwfc:  48  5P  l=1, m=1
#       atwfc:  49  5P  l=1, m=2
#       atwfc:  50  5P  l=1, m=3
#       atwfc:  51  5D  l=2, m=1
#       atwfc:  52  5D  l=2, m=2
#       atwfc:  53  5D  l=2, m=3
#       atwfc:  54  5D  l=2, m=4
#       atwfc:  55  5D  l=2, m=5
#       atwfc:  56  6S  l=0, m=1
#       atwfc:  57  6P  l=1, m=1
#       atwfc:  58  6P  l=1, m=2
#       atwfc:  59  6P  l=1, m=3
#       atwfc:  60  4F  l=3, m=1
#       atwfc:  61  4F  l=3, m=2
#       atwfc:  62  4F  l=3, m=3
#       atwfc:  63  4F  l=3, m=4
#       atwfc:  64  4F  l=3, m=5
#       atwfc:  65  4F  l=3, m=6
#       atwfc:  66  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 2.35404255  4.0773674  14.05033278]
#       atwfc:  67  5S  l=0, m=1
#       atwfc:  68  5P  l=1, m=1
#       atwfc:  69  5P  l=1, m=2
#       atwfc:  70  5P  l=1, m=3
#       atwfc:  71  5D  l=2, m=1
#       atwfc:  72  5D  l=2, m=2
#       atwfc:  73  5D  l=2, m=3
#       atwfc:  74  5D  l=2, m=4
#       atwfc:  75  5D  l=2, m=5
#       atwfc:  76  6S  l=0, m=1
#       atwfc:  77  6P  l=1, m=1
#       atwfc:  78  6P  l=1, m=2
#       atwfc:  79  6P  l=1, m=3
#       atwfc:  80  4F  l=3, m=1
#       atwfc:  81  4F  l=3, m=2
#       atwfc:  82  4F  l=3, m=3
#       atwfc:  83  4F  l=3, m=4
#       atwfc:  84  4F  l=3, m=5
#       atwfc:  85  4F  l=3, m=6
#       atwfc:  86  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-4.26746457  7.39151158 14.05033278]
#       atwfc:  87  5S  l=0, m=1
#       atwfc:  88  5P  l=1, m=1
#       atwfc:  89  5P  l=1, m=2
#       atwfc:  90  5P  l=1, m=3
#       atwfc:  91  5D  l=2, m=1
#       atwfc:  92  5D  l=2, m=2
#       atwfc:  93  5D  l=2, m=3
#       atwfc:  94  5D  l=2, m=4
#       atwfc:  95  5D  l=2, m=5
#       atwfc:  96  6S  l=0, m=1
#       atwfc:  97  6P  l=1, m=1
#       atwfc:  98  6P  l=1, m=2
#       atwfc:  99  6P  l=1, m=3
#       atwfc: 100  4F  l=3, m=1
#       atwfc: 101  4F  l=3, m=2
#       atwfc: 102  4F  l=3, m=3
#       atwfc: 103  4F  l=3, m=4
#       atwfc: 104  4F  l=3, m=5
#       atwfc: 105  4F  l=3, m=6
#       atwfc: 106  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-1.91342195 11.46883184 20.08480225]
#       atwfc: 107  5S  l=0, m=1
#       atwfc: 108  5P  l=1, m=1
#       atwfc: 109  5P  l=1, m=2
#       atwfc: 110  5P  l=1, m=3
#       atwfc: 111  5D  l=2, m=1
#       atwfc: 112  5D  l=2, m=2
#       atwfc: 113  5D  l=2, m=3
#       atwfc: 114  5D  l=2, m=4
#       atwfc: 115  5D  l=2, m=5
#       atwfc: 116  6S  l=0, m=1
#       atwfc: 117  6P  l=1, m=1
#       atwfc: 118  6P  l=1, m=2
#       atwfc: 119  6P  l=1, m=3
#       atwfc: 120  4F  l=3, m=1
#       atwfc: 121  4F  l=3, m=2
#       atwfc: 122  4F  l=3, m=3
#       atwfc: 123  4F  l=3, m=4
#       atwfc: 124  4F  l=3, m=5
#       atwfc: 125  4F  l=3, m=6
#       atwfc: 126  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 4.26746346  7.39151169 20.08480225]
#       atwfc: 127  5S  l=0, m=1
#       atwfc: 128  5P  l=1, m=1
#       atwfc: 129  5P  l=1, m=2
#       atwfc: 130  5P  l=1, m=3
#       atwfc: 131  5D  l=2, m=1
#       atwfc: 132  5D  l=2, m=2
#       atwfc: 133  5D  l=2, m=3
#       atwfc: 134  5D  l=2, m=4
#       atwfc: 135  5D  l=2, m=5
#       atwfc: 136  6S  l=0, m=1
#       atwfc: 137  6P  l=1, m=1
#       atwfc: 138  6P  l=1, m=2
#       atwfc: 139  6P  l=1, m=3
#       atwfc: 140  4F  l=3, m=1
#       atwfc: 141  4F  l=3, m=2
#       atwfc: 142  4F  l=3, m=3
#       atwfc: 143  4F  l=3, m=4
#       atwfc: 144  4F  l=3, m=5
#       atwfc: 145  4F  l=3, m=6
#       atwfc: 146  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-2.35404175  4.07736832 20.08480225]
#       atwfc: 147  5S  l=0, m=1
#       atwfc: 148  5P  l=1, m=1
#       atwfc: 149  5P  l=1, m=2
#       atwfc: 150  5P  l=1, m=3
#       atwfc: 151  5D  l=2, m=1
#       atwfc: 152  5D  l=2, m=2
#       atwfc: 153  5D  l=2, m=3
#       atwfc: 154  5D  l=2, m=4
#       atwfc: 155  5D  l=2, m=5
#       atwfc: 156  6S  l=0, m=1
#       atwfc: 157  6P  l=1, m=1
#       atwfc: 158  6P  l=1, m=2
#       atwfc: 159  6P  l=1, m=3
#       atwfc: 160  4F  l=3, m=1
#       atwfc: 161  4F  l=3, m=2
#       atwfc: 162  4F  l=3, m=3
#       atwfc: 163  4F  l=3, m=4
#       atwfc: 164  4F  l=3, m=5
#       atwfc: 165  4F  l=3, m=6
#       atwfc: 166  4F  l=3, m=7
# Projections in:                           393.020 sec

# %%
paoflow.projectability(pthr=0.85)
# Out:
# Projectability vector  [0.9362446  0.94083762 0.94916773 0.95320445 0.96117883 0.96355637
#  0.93074292 0.91840215 0.91646944 0.91902882 0.91783703 0.91911695
#  0.92547213 0.92070886 0.92635981 0.91338594 0.91527874 0.9040283
#  0.89291088 0.8956047  0.89496743 0.88854566 0.89171104 0.89446587
#  0.90104399 0.90003063 0.89479542 0.89331987 0.88944125 0.90002788
#  0.84519963 0.85459496 0.85023931 0.84611917 0.8723867  0.8630488
#  0.78300308 0.82431556 0.79376075 0.82098489]
# # of bands with good projectability > 0.85 = 34
# Range of suggested shift  4.42565194  ,  5.276651940000001
# Projectability in:                          0.037 sec

# %%
paoflow.pao_hamiltonian()
# Out:
# Building Hks in:                            1.565 sec
# k -> R in:                                  0.493 sec

# %%
path = 'G-M-K-G'
sym_points = {'G':[0.0, 0.0, 0.0],
            'M':[0.5, 0.0, 0.0],
            'K':[1/3, 1/3, 0.0]}
paoflow.bands(ibrav=0, nk=500, band_path = path, high_sym_points = sym_points)
# Out:
# Bands in:                                  36.355 sec

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
eband = arry['E_k']
ax[0].plot(eband[:,0,0],color='red',alpha=0.5,label="up")
ax[0].plot(eband[:,0,1],color='blue',alpha=0.5,label="down")
ax[1].plot(eband[:,0,0],color='red',alpha=0.5,label="up")
ax[1].plot(eband[:,0,1],color='blue',alpha=0.5,label="down")
for ib in range(1,eband.shape[1]):
    ax[0].plot(eband[:,ib,0],color='red',alpha=0.5)
    ax[0].plot(eband[:,ib,1],color='blue',alpha=0.5)
    ax[1].plot(eband[:,ib,0],color='red',alpha=0.5)
    ax[1].plot(eband[:,ib,1],color='blue',alpha=0.5)
    
ax[0].legend(loc=[0.05,0.2])
ax[1].legend(loc=[0.05,0.5])
ax[0].set_xlim([0,eband.shape[0]-1])
ax[1].set_xlim([0,eband.shape[0]-1])
ax[1].set_ylim([-1.5,1.5])
ax[0].set_ylabel("E (eV)")
plt.show()

# %% [markdown]
# # Example 07: CrI3 monolayer (with SOC, FM)

# %%
paoflow_soc = PAOFLOW(savedir='./example07/nscf_soc/',  
                  outputdir='./example07/output_soc/', 
                  verbose=True,
                  dft="VASP")
data_controller = paoflow_soc.data_controller
arry_soc,attr_soc = paoflow_soc.data_controller.data_dicts()
# Out:
# #############################################################################################
# #                                                                                           #
# #                                          PAOFLOW                                          #
# #                                                                                           #
# #                  Utility to construct and operate on Hamiltonians from                    #
# #                 the Projections of DFT wfc on Atomic Orbital bases (PAO)                  #
# #                                                                                           #
# #                       (c)2016-2024 ERMES group (http://ermes.unt.edu)                     #
# #############################################################################################
#
# VASP version: 6.2.0
# Monkhorst and Pack grid: 10 10 1 0 0 0
# Space group: P-31m (162)
# Insulator: True
# Magnetic: True
# Number of kpoints: 18
# Number of electrons: 54.000000
# Number of bands: 80
# SciPy will perform FFTs
# Serial execution
# Estimated maximum array size: 0.12 GBytes
#
# Initialization in:                          0.019 sec

# %%
basis_path = '../../BASIS/'
basis_config = {'Cr':['3D','4S','4P','4D','5S','5P','5D'],
                'I':['5S','5P','5D','6S','6P','4F']}
paoflow_soc.projections(basispath=basis_path, configuration=basis_config)
# Out:
# atom: Cr  AEWFC: ../../BASIS/Cr\3D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4S.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4P.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\4D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5S.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5P.dat           tau: [ 6.62154732  3.82295205 17.06756766]
# atom: Cr  AEWFC: ../../BASIS/Cr\5D.dat           tau: [ 6.62154732  3.82295205 17.06756766]
#       atwfc:   1  3D  l=2, m=1
#       atwfc:   2  3D  l=2, m=2
#       atwfc:   3  3D  l=2, m=3
#       atwfc:   4  3D  l=2, m=4
#       atwfc:   5  3D  l=2, m=5
#       atwfc:   6  3D  l=2, m=1
#       atwfc:   7  3D  l=2, m=2
#       atwfc:   8  3D  l=2, m=3
#       atwfc:   9  3D  l=2, m=4
#       atwfc:  10  3D  l=2, m=5
#       atwfc:  11  4S  l=0, m=1
#       atwfc:  12  4S  l=0, m=1
#       atwfc:  13  4P  l=1, m=1
#       atwfc:  14  4P  l=1, m=2
#       atwfc:  15  4P  l=1, m=3
#       atwfc:  16  4P  l=1, m=1
#       atwfc:  17  4P  l=1, m=2
#       atwfc:  18  4P  l=1, m=3
#       atwfc:  19  4D  l=2, m=1
#       atwfc:  20  4D  l=2, m=2
#       atwfc:  21  4D  l=2, m=3
#       atwfc:  22  4D  l=2, m=4
#       atwfc:  23  4D  l=2, m=5
#       atwfc:  24  4D  l=2, m=1
#       atwfc:  25  4D  l=2, m=2
#       atwfc:  26  4D  l=2, m=3
#       atwfc:  27  4D  l=2, m=4
#       atwfc:  28  4D  l=2, m=5
#       atwfc:  29  5S  l=0, m=1
#       atwfc:  30  5S  l=0, m=1
#       atwfc:  31  5P  l=1, m=1
#       atwfc:  32  5P  l=1, m=2
#       atwfc:  33  5P  l=1, m=3
#       atwfc:  34  5P  l=1, m=1
#       atwfc:  35  5P  l=1, m=2
#       atwfc:  36  5P  l=1, m=3
#       atwfc:  37  5D  l=2, m=1
#       atwfc:  38  5D  l=2, m=2
#       atwfc:  39  5D  l=2, m=3
#       atwfc:  40  5D  l=2, m=4
#       atwfc:  41  5D  l=2, m=5
#       atwfc:  42  5D  l=2, m=1
#       atwfc:  43  5D  l=2, m=2
#       atwfc:  44  5D  l=2, m=3
#       atwfc:  45  5D  l=2, m=4
#       atwfc:  46  5D  l=2, m=5
# atom: Cr  AEWFC: ../../BASIS/Cr\3D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4S.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4P.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\4D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5S.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5P.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
# atom: Cr  AEWFC: ../../BASIS/Cr\5D.dat           tau: [-5.99163831e-08  7.64590422e+00  1.70675657e+01]
#       atwfc:  47  3D  l=2, m=1
#       atwfc:  48  3D  l=2, m=2
#       atwfc:  49  3D  l=2, m=3
#       atwfc:  50  3D  l=2, m=4
#       atwfc:  51  3D  l=2, m=5
#       atwfc:  52  3D  l=2, m=1
#       atwfc:  53  3D  l=2, m=2
#       atwfc:  54  3D  l=2, m=3
#       atwfc:  55  3D  l=2, m=4
#       atwfc:  56  3D  l=2, m=5
#       atwfc:  57  4S  l=0, m=1
#       atwfc:  58  4S  l=0, m=1
#       atwfc:  59  4P  l=1, m=1
#       atwfc:  60  4P  l=1, m=2
#       atwfc:  61  4P  l=1, m=3
#       atwfc:  62  4P  l=1, m=1
#       atwfc:  63  4P  l=1, m=2
#       atwfc:  64  4P  l=1, m=3
#       atwfc:  65  4D  l=2, m=1
#       atwfc:  66  4D  l=2, m=2
#       atwfc:  67  4D  l=2, m=3
#       atwfc:  68  4D  l=2, m=4
#       atwfc:  69  4D  l=2, m=5
#       atwfc:  70  4D  l=2, m=1
#       atwfc:  71  4D  l=2, m=2
#       atwfc:  72  4D  l=2, m=3
#       atwfc:  73  4D  l=2, m=4
#       atwfc:  74  4D  l=2, m=5
#       atwfc:  75  5S  l=0, m=1
#       atwfc:  76  5S  l=0, m=1
#       atwfc:  77  5P  l=1, m=1
#       atwfc:  78  5P  l=1, m=2
#       atwfc:  79  5P  l=1, m=3
#       atwfc:  80  5P  l=1, m=1
#       atwfc:  81  5P  l=1, m=2
#       atwfc:  82  5P  l=1, m=3
#       atwfc:  83  5D  l=2, m=1
#       atwfc:  84  5D  l=2, m=2
#       atwfc:  85  5D  l=2, m=3
#       atwfc:  86  5D  l=2, m=4
#       atwfc:  87  5D  l=2, m=5
#       atwfc:  88  5D  l=2, m=1
#       atwfc:  89  5D  l=2, m=2
#       atwfc:  90  5D  l=2, m=3
#       atwfc:  91  5D  l=2, m=4
#       atwfc:  92  5D  l=2, m=5
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 1.91342204 11.46883288 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 1.91342204 11.46883288 14.05033278]
#       atwfc:  93  5S  l=0, m=1
#       atwfc:  94  5S  l=0, m=1
#       atwfc:  95  5P  l=1, m=1
#       atwfc:  96  5P  l=1, m=2
#       atwfc:  97  5P  l=1, m=3
#       atwfc:  98  5P  l=1, m=1
#       atwfc:  99  5P  l=1, m=2
#       atwfc: 100  5P  l=1, m=3
#       atwfc: 101  5D  l=2, m=1
#       atwfc: 102  5D  l=2, m=2
#       atwfc: 103  5D  l=2, m=3
#       atwfc: 104  5D  l=2, m=4
#       atwfc: 105  5D  l=2, m=5
#       atwfc: 106  5D  l=2, m=1
#       atwfc: 107  5D  l=2, m=2
#       atwfc: 108  5D  l=2, m=3
#       atwfc: 109  5D  l=2, m=4
#       atwfc: 110  5D  l=2, m=5
#       atwfc: 111  6S  l=0, m=1
#       atwfc: 112  6S  l=0, m=1
#       atwfc: 113  6P  l=1, m=1
#       atwfc: 114  6P  l=1, m=2
#       atwfc: 115  6P  l=1, m=3
#       atwfc: 116  6P  l=1, m=1
#       atwfc: 117  6P  l=1, m=2
#       atwfc: 118  6P  l=1, m=3
#       atwfc: 119  4F  l=3, m=1
#       atwfc: 120  4F  l=3, m=2
#       atwfc: 121  4F  l=3, m=3
#       atwfc: 122  4F  l=3, m=4
#       atwfc: 123  4F  l=3, m=5
#       atwfc: 124  4F  l=3, m=6
#       atwfc: 125  4F  l=3, m=7
#       atwfc: 126  4F  l=3, m=1
#       atwfc: 127  4F  l=3, m=2
#       atwfc: 128  4F  l=3, m=3
#       atwfc: 129  4F  l=3, m=4
#       atwfc: 130  4F  l=3, m=5
#       atwfc: 131  4F  l=3, m=6
#       atwfc: 132  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 2.35404255  4.0773674  14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 2.35404255  4.0773674  14.05033278]
#       atwfc: 133  5S  l=0, m=1
#       atwfc: 134  5S  l=0, m=1
#       atwfc: 135  5P  l=1, m=1
#       atwfc: 136  5P  l=1, m=2
#       atwfc: 137  5P  l=1, m=3
#       atwfc: 138  5P  l=1, m=1
#       atwfc: 139  5P  l=1, m=2
#       atwfc: 140  5P  l=1, m=3
#       atwfc: 141  5D  l=2, m=1
#       atwfc: 142  5D  l=2, m=2
#       atwfc: 143  5D  l=2, m=3
#       atwfc: 144  5D  l=2, m=4
#       atwfc: 145  5D  l=2, m=5
#       atwfc: 146  5D  l=2, m=1
#       atwfc: 147  5D  l=2, m=2
#       atwfc: 148  5D  l=2, m=3
#       atwfc: 149  5D  l=2, m=4
#       atwfc: 150  5D  l=2, m=5
#       atwfc: 151  6S  l=0, m=1
#       atwfc: 152  6S  l=0, m=1
#       atwfc: 153  6P  l=1, m=1
#       atwfc: 154  6P  l=1, m=2
#       atwfc: 155  6P  l=1, m=3
#       atwfc: 156  6P  l=1, m=1
#       atwfc: 157  6P  l=1, m=2
#       atwfc: 158  6P  l=1, m=3
#       atwfc: 159  4F  l=3, m=1
#       atwfc: 160  4F  l=3, m=2
#       atwfc: 161  4F  l=3, m=3
#       atwfc: 162  4F  l=3, m=4
#       atwfc: 163  4F  l=3, m=5
#       atwfc: 164  4F  l=3, m=6
#       atwfc: 165  4F  l=3, m=7
#       atwfc: 166  4F  l=3, m=1
#       atwfc: 167  4F  l=3, m=2
#       atwfc: 168  4F  l=3, m=3
#       atwfc: 169  4F  l=3, m=4
#       atwfc: 170  4F  l=3, m=5
#       atwfc: 171  4F  l=3, m=6
#       atwfc: 172  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-4.26746457  7.39151158 14.05033278]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-4.26746457  7.39151158 14.05033278]
#       atwfc: 173  5S  l=0, m=1
#       atwfc: 174  5S  l=0, m=1
#       atwfc: 175  5P  l=1, m=1
#       atwfc: 176  5P  l=1, m=2
#       atwfc: 177  5P  l=1, m=3
#       atwfc: 178  5P  l=1, m=1
#       atwfc: 179  5P  l=1, m=2
#       atwfc: 180  5P  l=1, m=3
#       atwfc: 181  5D  l=2, m=1
#       atwfc: 182  5D  l=2, m=2
#       atwfc: 183  5D  l=2, m=3
#       atwfc: 184  5D  l=2, m=4
#       atwfc: 185  5D  l=2, m=5
#       atwfc: 186  5D  l=2, m=1
#       atwfc: 187  5D  l=2, m=2
#       atwfc: 188  5D  l=2, m=3
#       atwfc: 189  5D  l=2, m=4
#       atwfc: 190  5D  l=2, m=5
#       atwfc: 191  6S  l=0, m=1
#       atwfc: 192  6S  l=0, m=1
#       atwfc: 193  6P  l=1, m=1
#       atwfc: 194  6P  l=1, m=2
#       atwfc: 195  6P  l=1, m=3
#       atwfc: 196  6P  l=1, m=1
#       atwfc: 197  6P  l=1, m=2
#       atwfc: 198  6P  l=1, m=3
#       atwfc: 199  4F  l=3, m=1
#       atwfc: 200  4F  l=3, m=2
#       atwfc: 201  4F  l=3, m=3
#       atwfc: 202  4F  l=3, m=4
#       atwfc: 203  4F  l=3, m=5
#       atwfc: 204  4F  l=3, m=6
#       atwfc: 205  4F  l=3, m=7
#       atwfc: 206  4F  l=3, m=1
#       atwfc: 207  4F  l=3, m=2
#       atwfc: 208  4F  l=3, m=3
#       atwfc: 209  4F  l=3, m=4
#       atwfc: 210  4F  l=3, m=5
#       atwfc: 211  4F  l=3, m=6
#       atwfc: 212  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-1.91342195 11.46883184 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-1.91342195 11.46883184 20.08480225]
#       atwfc: 213  5S  l=0, m=1
#       atwfc: 214  5S  l=0, m=1
#       atwfc: 215  5P  l=1, m=1
#       atwfc: 216  5P  l=1, m=2
#       atwfc: 217  5P  l=1, m=3
#       atwfc: 218  5P  l=1, m=1
#       atwfc: 219  5P  l=1, m=2
#       atwfc: 220  5P  l=1, m=3
#       atwfc: 221  5D  l=2, m=1
#       atwfc: 222  5D  l=2, m=2
#       atwfc: 223  5D  l=2, m=3
#       atwfc: 224  5D  l=2, m=4
#       atwfc: 225  5D  l=2, m=5
#       atwfc: 226  5D  l=2, m=1
#       atwfc: 227  5D  l=2, m=2
#       atwfc: 228  5D  l=2, m=3
#       atwfc: 229  5D  l=2, m=4
#       atwfc: 230  5D  l=2, m=5
#       atwfc: 231  6S  l=0, m=1
#       atwfc: 232  6S  l=0, m=1
#       atwfc: 233  6P  l=1, m=1
#       atwfc: 234  6P  l=1, m=2
#       atwfc: 235  6P  l=1, m=3
#       atwfc: 236  6P  l=1, m=1
#       atwfc: 237  6P  l=1, m=2
#       atwfc: 238  6P  l=1, m=3
#       atwfc: 239  4F  l=3, m=1
#       atwfc: 240  4F  l=3, m=2
#       atwfc: 241  4F  l=3, m=3
#       atwfc: 242  4F  l=3, m=4
#       atwfc: 243  4F  l=3, m=5
#       atwfc: 244  4F  l=3, m=6
#       atwfc: 245  4F  l=3, m=7
#       atwfc: 246  4F  l=3, m=1
#       atwfc: 247  4F  l=3, m=2
#       atwfc: 248  4F  l=3, m=3
#       atwfc: 249  4F  l=3, m=4
#       atwfc: 250  4F  l=3, m=5
#       atwfc: 251  4F  l=3, m=6
#       atwfc: 252  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [ 4.26746346  7.39151169 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [ 4.26746346  7.39151169 20.08480225]
#       atwfc: 253  5S  l=0, m=1
#       atwfc: 254  5S  l=0, m=1
#       atwfc: 255  5P  l=1, m=1
#       atwfc: 256  5P  l=1, m=2
#       atwfc: 257  5P  l=1, m=3
#       atwfc: 258  5P  l=1, m=1
#       atwfc: 259  5P  l=1, m=2
#       atwfc: 260  5P  l=1, m=3
#       atwfc: 261  5D  l=2, m=1
#       atwfc: 262  5D  l=2, m=2
#       atwfc: 263  5D  l=2, m=3
#       atwfc: 264  5D  l=2, m=4
#       atwfc: 265  5D  l=2, m=5
#       atwfc: 266  5D  l=2, m=1
#       atwfc: 267  5D  l=2, m=2
#       atwfc: 268  5D  l=2, m=3
#       atwfc: 269  5D  l=2, m=4
#       atwfc: 270  5D  l=2, m=5
#       atwfc: 271  6S  l=0, m=1
#       atwfc: 272  6S  l=0, m=1
#       atwfc: 273  6P  l=1, m=1
#       atwfc: 274  6P  l=1, m=2
#       atwfc: 275  6P  l=1, m=3
#       atwfc: 276  6P  l=1, m=1
#       atwfc: 277  6P  l=1, m=2
#       atwfc: 278  6P  l=1, m=3
#       atwfc: 279  4F  l=3, m=1
#       atwfc: 280  4F  l=3, m=2
#       atwfc: 281  4F  l=3, m=3
#       atwfc: 282  4F  l=3, m=4
#       atwfc: 283  4F  l=3, m=5
#       atwfc: 284  4F  l=3, m=6
#       atwfc: 285  4F  l=3, m=7
#       atwfc: 286  4F  l=3, m=1
#       atwfc: 287  4F  l=3, m=2
#       atwfc: 288  4F  l=3, m=3
#       atwfc: 289  4F  l=3, m=4
#       atwfc: 290  4F  l=3, m=5
#       atwfc: 291  4F  l=3, m=6
#       atwfc: 292  4F  l=3, m=7
# atom: I   AEWFC: ../../BASIS/I\5S.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5P.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\5D.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6S.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\6P.dat            tau: [-2.35404175  4.07736832 20.08480225]
# atom: I   AEWFC: ../../BASIS/I\4F.dat            tau: [-2.35404175  4.07736832 20.08480225]
#       atwfc: 293  5S  l=0, m=1
#       atwfc: 294  5S  l=0, m=1
#       atwfc: 295  5P  l=1, m=1
#       atwfc: 296  5P  l=1, m=2
#       atwfc: 297  5P  l=1, m=3
#       atwfc: 298  5P  l=1, m=1
#       atwfc: 299  5P  l=1, m=2
#       atwfc: 300  5P  l=1, m=3
#       atwfc: 301  5D  l=2, m=1
#       atwfc: 302  5D  l=2, m=2
#       atwfc: 303  5D  l=2, m=3
#       atwfc: 304  5D  l=2, m=4
#       atwfc: 305  5D  l=2, m=5
#       atwfc: 306  5D  l=2, m=1
#       atwfc: 307  5D  l=2, m=2
#       atwfc: 308  5D  l=2, m=3
#       atwfc: 309  5D  l=2, m=4
#       atwfc: 310  5D  l=2, m=5
#       atwfc: 311  6S  l=0, m=1
#       atwfc: 312  6S  l=0, m=1
#       atwfc: 313  6P  l=1, m=1
#       atwfc: 314  6P  l=1, m=2
#       atwfc: 315  6P  l=1, m=3
#       atwfc: 316  6P  l=1, m=1
#       atwfc: 317  6P  l=1, m=2
#       atwfc: 318  6P  l=1, m=3
#       atwfc: 319  4F  l=3, m=1
#       atwfc: 320  4F  l=3, m=2
#       atwfc: 321  4F  l=3, m=3
#       atwfc: 322  4F  l=3, m=4
#       atwfc: 323  4F  l=3, m=5
#       atwfc: 324  4F  l=3, m=6
#       atwfc: 325  4F  l=3, m=7
#       atwfc: 326  4F  l=3, m=1
#       atwfc: 327  4F  l=3, m=2
#       atwfc: 328  4F  l=3, m=3
#       atwfc: 329  4F  l=3, m=4
#       atwfc: 330  4F  l=3, m=5
#       atwfc: 331  4F  l=3, m=6
#       atwfc: 332  4F  l=3, m=7
# Projections in:                           948.707 sec

# %%
paoflow_soc.projectability(pthr=0.85)
# Out:
# Projectability vector  [0.93721596 0.93766069 0.94214036 0.94335755 0.94963527 0.95100183
#  0.95093558 0.95675729 0.95535483 0.96283537 0.96047264 0.9628381
#  0.93146059 0.92193814 0.91870885 0.9094278  0.91434744 0.90797141
#  0.91012109 0.91024122 0.91071179 0.91238524 0.92062354 0.91842742
#  0.92069083 0.92152968 0.92221033 0.91605633 0.91804282 0.91312253
#  0.91196278 0.9064835  0.90420678 0.89902507 0.90792655 0.90243768
#  0.90057773 0.89836203 0.89797135 0.89239757 0.89402205 0.89787031
#  0.89409962 0.89070486 0.8880311  0.89132725 0.89414244 0.89041264
#  0.88986188 0.89580108 0.89648901 0.90028714 0.9077727  0.90727945
#  0.82784971 0.83790312 0.83923743 0.84290216 0.92181014 0.92068479
#  0.90831557 0.90253356 0.88656363 0.89583035 0.86472087 0.87487658
#  0.86143071 0.85561591 0.92148883 0.87411978 0.82991604 0.86130923
#  0.78570975 0.7955482  0.77298453 0.84821935 0.82451095 0.78276624
#  0.83272059 0.80571242]
# # of bands with good projectability > 0.85 = 67
# Range of suggested shift  2.93212024  ,  3.07182024
# Projectability in:                          0.060 sec

# %%
paoflow_soc.pao_hamiltonian()
# Out:
# Building Hks in:                            3.352 sec
# k -> R in:                                  0.671 sec

# %%
path = 'G-M-K-G'
sym_points = {'G':[0.0, 0.0, 0.0],
            'M':[0.5, 0.0, 0.0],
            'K':[1/3, 1/3, 0.0]}
paoflow_soc.bands(ibrav=0, nk=500, band_path = path, high_sym_points = sym_points)
# Out:
# Bands in:                                  56.860 sec

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
eband = arry_soc['E_k']
for ib in range(eband.shape[1]):
    ax[0].plot(eband[:,ib],color='k',alpha=0.5)
    ax[1].plot(eband[:,ib],color='k',alpha=0.5)
ax[0].set_xlim([0,eband.shape[0]-1])
ax[1].set_xlim([0,eband.shape[0]-1])
ax[1].set_ylim([-1.5,1.5])
ax[0].set_ylabel("E (eV)")
plt.show()
